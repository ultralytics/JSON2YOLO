# %% [markdown]
# <a href="https://colab.research.google.com/github/ryouchinsa/JSON2YOLO/blob/master/train_yolo26_classification_on_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Train a YOLO26 Classification Model with Custom Data
#
# We will show you how to train a YOLO26 classification model with your images and annotations and export to a Core ML model which can be used for auto labeling on RectLabel.

# %% [markdown]
# ### Use GPU
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Runtime` -> `Change runtime type` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Mar 29 09:04:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install YOLO26

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.3 MB/s eta 0:00:00

# %% [markdown]
# ### Download training images and annotations
#
# Download training images and annotations. You can use these or replace them with your own data.

# %%
# !wget -q https://huggingface.co/datasets/rectlabel/datasets/resolve/main/converse_vans_classification.zip
# !unzip -q converse_vans_classification.zip

# %% [markdown]
# ### Fine-tune YOLO26 on custom dataset

# %%
# !yolo classify train data=converse_vans_classification model=yolo26n-cls.pt epochs=100
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n-cls.pt to 'yolo26n-cls.pt': 100% ━━━━━━━━━━━━ 5.5MB 103.5MB/s 0.1s
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=converse_vans_classification, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/classify/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /content/converse_vans_classification/train... found 710 images in 2 classes ✅
# val: /content/converse_vans_classification/valid... found 99 images in 2 classes ✅
# test: /content/converse_vans_classification/test... found 85 images in 2 classes ✅
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLO26n-cls summary: 86 layers, 1,533,666 parameters, 1,533,666 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 100.4MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 724.7±610.3 MB/s, size: 17.0 KB)
# train: Scanning /content/converse_vans_classification/train... 710 images, 0 corrupt: 100% ━━━━━━━━━━━━ 710/710 6.2Kit/s 0.1s
# train: New cache created: /content/converse_vans_classification/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 280.9±109.3 MB/s, size: 21.9 KB)
# val: Scanning /content/converse_vans_classification/valid... 99 images, 0 corrupt: 100% ━━━━━━━━━━━━ 99/99 7.5Kit/s 0.0s
# val: New cache created: /content/converse_vans_classification/valid.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to /content/runs/classify/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 22.4MB/s 0.0s
#       1/100     0.279G     0.5253          6        224: 100% ━━━━━━━━━━━━ 45/45 4.7it/s 9.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.8it/s 1.0s
#                    all      0.778          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100     0.279G     0.3719          6        224: 100% ━━━━━━━━━━━━ 45/45 8.3it/s 5.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 23.4it/s 0.2s
#                    all      0.879          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100     0.279G     0.3518          6        224: 100% ━━━━━━━━━━━━ 45/45 10.8it/s 4.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 30.1it/s 0.1s
#                    all      0.838          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100     0.279G     0.3069          6        224: 100% ━━━━━━━━━━━━ 45/45 10.3it/s 4.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 31.7it/s 0.1s
#                    all      0.818          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100     0.279G     0.3244          6        224: 100% ━━━━━━━━━━━━ 45/45 9.1it/s 5.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 18.1it/s 0.2s
#                    all      0.859          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100     0.279G     0.3237          6        224: 100% ━━━━━━━━━━━━ 45/45 11.2it/s 4.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 30.6it/s 0.1s
#                    all      0.859          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100     0.279G      0.309          6        224: 100% ━━━━━━━━━━━━ 45/45 8.3it/s 5.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.5it/s 0.2s
#                    all      0.768          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100     0.279G     0.2241          6        224: 100% ━━━━━━━━━━━━ 45/45 10.4it/s 4.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 24.7it/s 0.2s
#                    all      0.848          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100     0.279G      0.221          6        224: 100% ━━━━━━━━━━━━ 45/45 11.5it/s 3.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 17.8it/s 0.2s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100     0.279G     0.2268          6        224: 100% ━━━━━━━━━━━━ 45/45 8.9it/s 5.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 28.0it/s 0.1s
#                    all      0.838          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100     0.279G     0.2469          6        224: 100% ━━━━━━━━━━━━ 45/45 11.1it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 24.9it/s 0.2s
#                    all      0.869          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100     0.279G     0.2303          6        224: 100% ━━━━━━━━━━━━ 45/45 8.8it/s 5.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.5it/s 0.2s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100     0.279G     0.2715          6        224: 100% ━━━━━━━━━━━━ 45/45 11.6it/s 3.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 19.1it/s 0.2s
#                    all      0.889          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100     0.279G     0.2129          6        224: 100% ━━━━━━━━━━━━ 45/45 11.5it/s 3.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 30.8it/s 0.1s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100     0.279G     0.2203          6        224: 100% ━━━━━━━━━━━━ 45/45 8.4it/s 5.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 35.3it/s 0.1s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100     0.279G      0.148          6        224: 100% ━━━━━━━━━━━━ 45/45 11.4it/s 4.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 20.8it/s 0.2s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100     0.279G     0.1667          6        224: 100% ━━━━━━━━━━━━ 45/45 9.5it/s 4.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 16.5it/s 0.2s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100     0.279G     0.1581          6        224: 100% ━━━━━━━━━━━━ 45/45 11.0it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.3it/s 0.2s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100     0.279G     0.1626          6        224: 100% ━━━━━━━━━━━━ 45/45 11.6it/s 3.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 39.1it/s 0.1s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100     0.279G      0.169          6        224: 100% ━━━━━━━━━━━━ 45/45 8.5it/s 5.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 21.7it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100     0.279G     0.1713          6        224: 100% ━━━━━━━━━━━━ 45/45 11.1it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 19.8it/s 0.2s
#                    all      0.869          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100     0.279G     0.1442          6        224: 100% ━━━━━━━━━━━━ 45/45 9.7it/s 4.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 14.1it/s 0.3s
#                    all      0.848          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100     0.279G     0.1638          6        224: 100% ━━━━━━━━━━━━ 45/45 10.6it/s 4.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.8it/s 0.2s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100     0.279G     0.1219          6        224: 100% ━━━━━━━━━━━━ 45/45 11.3it/s 4.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 27.8it/s 0.1s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100     0.279G     0.1609          6        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 21.3it/s 0.2s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100     0.279G     0.1446          6        224: 100% ━━━━━━━━━━━━ 45/45 11.9it/s 3.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 21.4it/s 0.2s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100     0.279G     0.1486          6        224: 100% ━━━━━━━━━━━━ 45/45 11.8it/s 3.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 15.7it/s 0.3s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100     0.279G     0.1227          6        224: 100% ━━━━━━━━━━━━ 45/45 9.1it/s 4.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 26.1it/s 0.2s
#                    all      0.869          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100     0.279G     0.1453          6        224: 100% ━━━━━━━━━━━━ 45/45 11.4it/s 3.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 25.7it/s 0.2s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100     0.279G    0.09813          6        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 19.6it/s 0.2s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      31/100     0.279G     0.1337          6        224: 100% ━━━━━━━━━━━━ 45/45 12.2it/s 3.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 23.8it/s 0.2s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      32/100     0.279G     0.1144          6        224: 100% ━━━━━━━━━━━━ 45/45 11.0it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 19.9it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      33/100     0.279G     0.1042          6        224: 100% ━━━━━━━━━━━━ 45/45 8.4it/s 5.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 27.6it/s 0.1s
#                    all      0.889          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      34/100     0.279G     0.1207          6        224: 100% ━━━━━━━━━━━━ 45/45 11.0it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 21.3it/s 0.2s
#                    all      0.889          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      35/100     0.279G     0.1433          6        224: 100% ━━━━━━━━━━━━ 45/45 8.8it/s 5.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 16.9it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      36/100     0.279G    0.09127          6        224: 100% ━━━━━━━━━━━━ 45/45 11.0it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 27.6it/s 0.1s
#                    all      0.879          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      37/100     0.279G     0.1206          6        224: 100% ━━━━━━━━━━━━ 45/45 11.0it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 23.5it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      38/100     0.279G     0.1019          6        224: 100% ━━━━━━━━━━━━ 45/45 8.4it/s 5.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 29.8it/s 0.1s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/100     0.279G     0.1018          6        224: 100% ━━━━━━━━━━━━ 45/45 10.2it/s 4.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 24.4it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      40/100     0.279G     0.1007          6        224: 100% ━━━━━━━━━━━━ 45/45 8.5it/s 5.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 21.1it/s 0.2s
#                    all      0.879          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      41/100     0.279G    0.06724          6        224: 100% ━━━━━━━━━━━━ 45/45 11.7it/s 3.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 42.1it/s 0.1s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      42/100     0.279G     0.1221          6        224: 100% ━━━━━━━━━━━━ 45/45 10.4it/s 4.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 57.5it/s 0.1s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      43/100     0.279G     0.1264          6        224: 100% ━━━━━━━━━━━━ 45/45 7.8it/s 5.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.0it/s 0.2s
#                    all      0.889          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      44/100     0.279G    0.09915          6        224: 100% ━━━━━━━━━━━━ 45/45 11.0it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 19.2it/s 0.2s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      45/100     0.279G    0.09062          6        224: 100% ━━━━━━━━━━━━ 45/45 8.3it/s 5.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 19.8it/s 0.2s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      46/100     0.279G    0.08115          6        224: 100% ━━━━━━━━━━━━ 45/45 11.1it/s 4.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 26.6it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      47/100     0.279G    0.07445          6        224: 100% ━━━━━━━━━━━━ 45/45 11.2it/s 4.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 35.8it/s 0.1s
#                    all      0.949          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      48/100     0.279G    0.05342          6        224: 100% ━━━━━━━━━━━━ 45/45 8.6it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 36.4it/s 0.1s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      49/100     0.279G    0.05369          6        224: 100% ━━━━━━━━━━━━ 45/45 10.1it/s 4.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 35.5it/s 0.1s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      50/100     0.279G    0.08059          6        224: 100% ━━━━━━━━━━━━ 45/45 9.0it/s 5.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 25.9it/s 0.2s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      51/100     0.279G    0.06269          6        224: 100% ━━━━━━━━━━━━ 45/45 11.3it/s 4.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 37.1it/s 0.1s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      52/100     0.279G    0.07839          6        224: 100% ━━━━━━━━━━━━ 45/45 10.5it/s 4.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 19.3it/s 0.2s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      53/100     0.279G    0.09633          6        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 26.5it/s 0.2s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      54/100     0.279G    0.08749          6        224: 100% ━━━━━━━━━━━━ 45/45 10.8it/s 4.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 24.3it/s 0.2s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      55/100     0.279G    0.09049          6        224: 100% ━━━━━━━━━━━━ 45/45 8.6it/s 5.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 16.7it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      56/100     0.279G    0.05445          6        224: 100% ━━━━━━━━━━━━ 45/45 11.6it/s 3.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 31.5it/s 0.1s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      57/100     0.279G    0.05174          6        224: 100% ━━━━━━━━━━━━ 45/45 10.9it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 21.0it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      58/100     0.279G    0.06068          6        224: 100% ━━━━━━━━━━━━ 45/45 8.6it/s 5.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 26.2it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      59/100     0.279G    0.05271          6        224: 100% ━━━━━━━━━━━━ 45/45 11.1it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 21.3it/s 0.2s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      60/100     0.279G     0.0469          6        224: 100% ━━━━━━━━━━━━ 45/45 9.1it/s 4.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 16.9it/s 0.2s
#                    all      0.949          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      61/100     0.279G    0.03968          6        224: 100% ━━━━━━━━━━━━ 45/45 10.8it/s 4.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 32.0it/s 0.1s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      62/100     0.279G    0.03811          6        224: 100% ━━━━━━━━━━━━ 45/45 11.4it/s 4.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 25.3it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      63/100     0.279G    0.05325          6        224: 100% ━━━━━━━━━━━━ 45/45 9.0it/s 5.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.2it/s 0.2s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      64/100     0.279G    0.04596          6        224: 100% ━━━━━━━━━━━━ 45/45 10.8it/s 4.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 32.4it/s 0.1s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      65/100     0.279G    0.05598          6        224: 100% ━━━━━━━━━━━━ 45/45 9.1it/s 4.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 18.2it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      66/100     0.279G    0.04273          6        224: 100% ━━━━━━━━━━━━ 45/45 10.6it/s 4.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 27.6it/s 0.1s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      67/100     0.279G    0.05609          6        224: 100% ━━━━━━━━━━━━ 45/45 10.5it/s 4.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.5it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      68/100     0.279G    0.04759          6        224: 100% ━━━━━━━━━━━━ 45/45 8.1it/s 5.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.2it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      69/100     0.279G    0.04269          6        224: 100% ━━━━━━━━━━━━ 45/45 11.4it/s 4.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 32.1it/s 0.1s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      70/100     0.279G    0.03623          6        224: 100% ━━━━━━━━━━━━ 45/45 8.9it/s 5.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 15.2it/s 0.3s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      71/100     0.279G     0.0283          6        224: 100% ━━━━━━━━━━━━ 45/45 10.7it/s 4.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 20.1it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      72/100     0.279G    0.02884          6        224: 100% ━━━━━━━━━━━━ 45/45 11.1it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 51.1it/s 0.1s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      73/100     0.279G    0.02956          6        224: 100% ━━━━━━━━━━━━ 45/45 7.9it/s 5.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 26.6it/s 0.2s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      74/100     0.279G    0.03804          6        224: 100% ━━━━━━━━━━━━ 45/45 10.5it/s 4.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 27.0it/s 0.1s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      75/100     0.279G    0.02736          6        224: 100% ━━━━━━━━━━━━ 45/45 8.3it/s 5.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 18.7it/s 0.2s
#                    all      0.879          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      76/100     0.279G    0.01643          6        224: 100% ━━━━━━━━━━━━ 45/45 11.0it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 18.5it/s 0.2s
#                    all      0.899          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      77/100     0.279G     0.0372          6        224: 100% ━━━━━━━━━━━━ 45/45 9.9it/s 4.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 20.7it/s 0.2s
#                    all      0.889          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      78/100     0.279G    0.01363          6        224: 100% ━━━━━━━━━━━━ 45/45 8.9it/s 5.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 31.1it/s 0.1s
#                    all      0.909          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      79/100     0.279G    0.02641          6        224: 100% ━━━━━━━━━━━━ 45/45 10.5it/s 4.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 21.3it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      80/100     0.279G    0.01429          6        224: 100% ━━━━━━━━━━━━ 45/45 7.9it/s 5.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 23.1it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      81/100     0.279G    0.01836          6        224: 100% ━━━━━━━━━━━━ 45/45 10.3it/s 4.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 29.6it/s 0.1s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      82/100     0.279G    0.01858          6        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.8it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      83/100     0.279G    0.02121          6        224: 100% ━━━━━━━━━━━━ 45/45 9.6it/s 4.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 30.9it/s 0.1s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      84/100     0.279G    0.01902          6        224: 100% ━━━━━━━━━━━━ 45/45 10.2it/s 4.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 14.3it/s 0.3s
#                    all      0.949          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      85/100     0.279G     0.0346          6        224: 100% ━━━━━━━━━━━━ 45/45 8.5it/s 5.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 30.9it/s 0.1s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      86/100     0.279G    0.04351          6        224: 100% ━━━━━━━━━━━━ 45/45 10.3it/s 4.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 25.8it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      87/100     0.279G      0.031          6        224: 100% ━━━━━━━━━━━━ 45/45 8.0it/s 5.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 31.7it/s 0.1s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      88/100     0.279G    0.01584          6        224: 100% ━━━━━━━━━━━━ 45/45 9.9it/s 4.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 24.8it/s 0.2s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      89/100     0.279G    0.06206          6        224: 100% ━━━━━━━━━━━━ 45/45 9.5it/s 4.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 14.6it/s 0.3s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      90/100     0.279G    0.01497          6        224: 100% ━━━━━━━━━━━━ 45/45 9.9it/s 4.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 24.9it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      91/100     0.279G    0.01627          6        224: 100% ━━━━━━━━━━━━ 45/45 9.5it/s 4.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 20.7it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      92/100     0.279G    0.02579          6        224: 100% ━━━━━━━━━━━━ 45/45 8.4it/s 5.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 30.0it/s 0.1s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      93/100     0.279G    0.01434          6        224: 100% ━━━━━━━━━━━━ 45/45 11.1it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.9it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      94/100     0.279G    0.01804          6        224: 100% ━━━━━━━━━━━━ 45/45 8.0it/s 5.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 29.5it/s 0.1s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      95/100     0.279G    0.02273          6        224: 100% ━━━━━━━━━━━━ 45/45 10.9it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 23.1it/s 0.2s
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      96/100     0.279G    0.01749          6        224: 100% ━━━━━━━━━━━━ 45/45 10.1it/s 4.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 19.4it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      97/100     0.279G     0.0145          6        224: 100% ━━━━━━━━━━━━ 45/45 9.2it/s 4.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 19.1it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      98/100     0.279G    0.03558          6        224: 100% ━━━━━━━━━━━━ 45/45 10.9it/s 4.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 26.4it/s 0.2s
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      99/100     0.279G    0.01268          6        224: 100% ━━━━━━━━━━━━ 45/45 8.1it/s 5.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 22.1it/s 0.2s
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     100/100     0.279G    0.02553          6        224: 100% ━━━━━━━━━━━━ 45/45 10.6it/s 4.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 31.7it/s 0.1s
#                    all      0.939          1
#
# 100 epochs completed in 0.150 hours.
# Optimizer stripped from /content/runs/classify/train/weights/last.pt, 3.2MB
# Optimizer stripped from /content/runs/classify/train/weights/best.pt, 3.2MB
#
# Validating /content/runs/classify/train/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /content/converse_vans_classification/train... found 710 images in 2 classes ✅
# val: /content/converse_vans_classification/valid... found 99 images in 2 classes ✅
# test: /content/converse_vans_classification/test... found 85 images in 2 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 10.6it/s 0.4s
#                    all       0.96          1
# Speed: 0.5ms preprocess, 2.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# Here are trained models.

# %%
# !ls runs/classify/train/weights
# Out:
# best.pt  last.pt

# %% [markdown]
# Move the best model to the current folder and export to a Core ML model.

# %%
# !mv runs/classify/train/weights/best.pt .

# %%
# !yolo export model=best.pt format=coreml
# Out:
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 2) (3.0 MB)
# requirements: Ultralytics requirement ['coremltools>=9.0'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 261ms
# Prepared 3 packages in 134ms
# Installed 3 packages in 16ms
#  + cattrs==26.1.0
#  + coremltools==9.0
#  + pyaml==26.2.1
#
# requirements: AutoUpdate success ✅ 0.8s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774775667.835601    5056 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774775667.842567    5056 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774775667.860213    5056 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774775667.860238    5056 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774775667.860242    5056 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774775667.860245    5056 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/coremltools/optimize/torch/palettization/fake_palettize.py:82: SyntaxWarning: invalid escape sequence '\_'
#   n_bits (:obj:`int`): Number of palettization bits. There would be :math:`2^{n\_bits}` unique weights in the ``LUT``.
#
# CoreML: starting export with coremltools 9.0...
# Converting PyTorch Frontend ==> MIL Ops: 100% 361/362 [00:00<00:00, 3153.80 ops/s]
# Running MIL frontend_pytorch pipeline: 100% 5/5 [00:00<00:00, 207.56 passes/s]
# Running MIL default pipeline:   0% 0/95 [00:00<?, ? passes/s]/usr/local/lib/python3.12/dist-packages/coremltools/converters/mil/mil/passes/defs/preprocess.py:273: UserWarning: Output, '564', of the source model, has been renamed to 'var_564' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# Running MIL default pipeline: 100% 95/95 [00:00<00:00, 112.11 passes/s]
# Running MIL backend_mlprogram pipeline: 100% 12/12 [00:00<00:00, 202.85 passes/s]
# CoreML: export success ✅ 15.9s, saved as 'best.mlpackage' (3.0 MB)
#
# Export complete (16.2s)
# Results saved to /content
# Predict:         yolo predict task=classify model=best.mlpackage imgsz=224
# Validate:        yolo val task=classify model=best.mlpackage imgsz=224 data=converse_vans_classification
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# Zip the Core ML model and download it from the File browser at the left hand. You can auto label images using the Core ML model on RectLabel.

# %%
# !zip -r best.mlpackage.zip best.mlpackage
# Out:
#   adding: best.mlpackage/ (stored 0%)
#   adding: best.mlpackage/Manifest.json (deflated 60%)
#   adding: best.mlpackage/Data/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/model.mlmodel (deflated 87%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/weight.bin (deflated 7%)
